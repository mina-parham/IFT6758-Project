# %%
import sys
import pandas as pd
sys.path.append('../ift6758/data/')
from get_data import get_games_data
from tidy_data2 import tidy
from comet_ml import Experiment
import os

# %%
os.environ['COMET_API_KEY'] = 'c2REbE8eQaoRTP059ajV8VYn9'

# %%
data_train = pd.read_csv("train_2015_2018.csv", index_col=[0])

# %%
data_train.head()
# Out:
#    event_idx period_time  period     game_id      team_away_name  \
# 0          7       00:51       1  2015020001  Montréal Canadiens
# 1          9       01:05       1  2015020001  Montréal Canadiens
# 2         10       01:06       1  2015020001  Montréal Canadiens
# 3         13       01:53       1  2015020001  Montréal Canadiens
# 4         21       02:37       1  2015020001  Montréal Canadiens
#
#         team_home_name  is_goal  coordinate_x  coordinate_y   shot_type  ...  \
# 0  Toronto Maple Leafs        0         -55.0           6.0  Wrist Shot  ...
# 1  Toronto Maple Leafs        0         -79.0           0.0   Snap Shot  ...
# 2  Toronto Maple Leafs        0         -75.0          -1.0   Snap Shot  ...
# 3  Toronto Maple Leafs        0         -55.0         -36.0  Wrist Shot  ...
# 4  Toronto Maple Leafs        0         -61.0          -1.0      Tip-In  ...
#
#   number_friendly number_opposing power_play  distance from_last_distance  \
# ...

# %%
x = data_train[data_train['game_id'] == 2017021065]
x
# Out:
#         event_idx period_time  period     game_id team_away_name  \
# 217422         11       01:51       1  2017021065  Winnipeg Jets
# 217423         12       01:55       1  2017021065  Winnipeg Jets
# 217424         16       02:04       1  2017021065  Winnipeg Jets
# 217425         20       02:31       1  2017021065  Winnipeg Jets
# 217426         21       02:39       1  2017021065  Winnipeg Jets
#
#              team_home_name  is_goal  coordinate_x  coordinate_y   shot_type  \
# 217422  Washington Capitals        0         -50.0          36.0   Snap Shot
# 217423  Washington Capitals        0         -85.0         -25.0  Wrist Shot
# 217424  Washington Capitals        0          73.0         -16.0    Backhand
# 217425  Washington Capitals        0         -29.0          -6.0   Slap Shot
# 217426  Washington Capitals        0          23.0         -34.0  Wrist Shot
#
#         ... number_friendly number_opposing power_play  distance  \
# ...

# %%
COMET_API_KEY = os.environ.get("COMET_API_KEY")

# %%
experiment = Experiment(
    api_key=COMET_API_KEY,
    project_name="ift-6758",
    workspace="ift-6758-2",
)
experiment.log_dataframe_profile(
x, 
name='wpg_v_wsh_2017021065',  # keep this name
dataframe_format='csv'  # ensure you set this flag!
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ift-6758-2/ift-6758/849254e441dd461ab4cc9c0f94a8ffac
#
# COMET WARNING: pandas_profiling is required to log profile; ignoring
# {'profile': None,
#  'dataframe': {'web': 'https://www.comet.com/api/asset/download?assetId=1de93a4605724be6801ea665d99ab1b9&experimentKey=849254e441dd461ab4cc9c0f94a8ffac',
#   'api': 'https://www.comet.com/api/rest/v2/experiment/asset/get-asset?assetId=1de93a4605724be6801ea665d99ab1b9&experimentKey=849254e441dd461ab4cc9c0f94a8ffac',
#   'assetId': '1de93a4605724be6801ea665d99ab1b9'}}

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/ift-6758-2/ift-6758/849254e441dd461ab4cc9c0f94a8ffac
# COMET INFO:   Uploads:
# COMET INFO:     dataframe                : 1 (1.49 KB)
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (19.00 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO: ---------------------------
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The Python SDK has 3600 seconds to finish before aborting...
